# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# 1D ConvNet
def build_1d_convnet(input_shape, num_classes):
    model = models.Sequential()
    model.add(layers.Conv1D(32, 3, activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling1D(2))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    return model

# 2D ConvNet
def build_2d_convnet(input_shape, num_classes):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    return model

# Define your input shape and number of classes
input_shape_1d = (100, 1)  # Length of input sequence and number of channels
input_shape_2d = (28, 28, 1)  # Height, width, and number of channels for 2D images
num_classes = 10

# Build 1D ConvNet
model_1d = build_1d_convnet(input_shape_1d, num_classes)
model_1d.summary()

# Build 2D ConvNet
model_2d = build_2d_convnet(input_shape_2d, num_classes)
model_2d.summary()

# Compile and train the models
model_1d.compile(optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

model_2d.compile(optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

# Assuming you have your training and testing data
train_data_1d = ...
train_labels_1d = ...
test_data_1d = ...
test_labels_1d = ...

train_data_2d = ...
train_labels_2d = ...
test_data_2d = ...
test_labels_2d = ...

# Train the 1D ConvNet
model_1d.fit(train_data_1d, train_labels_1d, epochs=10, validation_data=(test_data_1d, test_labels_1d))

# Train the 2D ConvNet
model_2d.fit(train_data_2d, train_labels_2d, epochs=10, validation_data=(test_data_2d, test_labels_2d))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 98, 32)            128
#
#  max_pooling1d (MaxPooling1D  (None, 49, 32)           0
#  )
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 64)                100416
#
#  dense_1 (Dense)             (None, 10)                650
#
# ...
# Total params: 101,194
# Trainable params: 101,194
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
# ...
